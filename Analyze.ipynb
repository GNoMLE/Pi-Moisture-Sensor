# %%
import pandas as pd

# %matplotlib inline

# %%
columns = ['ts', 'sensor', 'temp', 'moisture']
df = pd.read_csv("long-test.csv", header=None, names=columns)
df.index = pd.to_datetime(df.ts, unit='s')

# %%
df.temp.plot()

# %%
pd.
# Out:
# <module 'pandas' from '/home/dmaust/anaconda2/envs/ipy3/lib/python3.7/site-packages/pandas/__init__.py'>
